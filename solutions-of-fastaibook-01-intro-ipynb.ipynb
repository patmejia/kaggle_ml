# %% [markdown]
# <a href="https://www.kaggle.com/code/patimejia/solutions-of-fastaibook-01-intro-ipynb?scriptVersionId=115616554" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Answers to the Questionnaire

# %% [markdown]
# >Imagine a deep learning model as a chef in a kitchen. The data is the ingredients and the math is the recipe. The GPU is the chef's assistant, helping to prepare the ingredients and cook the dish. The model is the finished dish, which is presented to the diners (the users of the model). The diners may not know exactly how the dish was made, but they can see the results and taste the flavors. Just like a good chef, a deep learning model relies on good ingredients and a well-crafted recipe to produce a delicious and satisfying result.

# %% [markdown]
# Welcome to the questionnaire solutions! Here you will find answers to the questions posed in the [Questionnaire](https://github.com/fastai/fastbook/blob/master/01_intro.ipynb). We hope these solutions will help you better understand the material and serve as a useful reference as you work through the exercises. If you have any questions or need further clarification, please don't hesitate to reach out to us. We welcome your feedback and suggestions for improvement. Let's get started!

# %% [markdown]
# 1. Do you need these for deep learning?
#
#    - Lots of math T / F
#    - Lots of data T / F
#    - Lots of expensive computers T / F
#    - A PhD T / F
#
# <br> R: You need lots of data and math, but not a PhD. A PhD will help you do research, but it's not necessary to use a deep learning method.
#
# 1. Name five areas where deep learning is now the best in the world.
# <br> R: Deep learning is now the best in the world in the following areas:
#    - Image classification
#    - Natural language processing
#    - Speech recognition
#    - Recommendation systems
#    - Generative adversarial networks
# 1. What was the name of the first device that was based on the principle of the artificial neuron?
# <br> R: The name of this device is sometimes called a "perceptron".
# 1. Based on the book of the same name, what are the requirements for parallel distributed processing (PDP)?
# <br> R: The requirements for PDP are:
#    - Parallelism: The system must process information in parallel.
#    - Distribution of representations: The system must distribute representations for information throughout the system.
#    - Propagation of activity: The system must propagate activity through the system.
#    - Localist coding: The system must use localist representations.
# 1. What were the two theoretical misunderstandings that held back the field of neural networks?
# <br> R: The two theoretical misunderstandings that held back the field of neural networks were:
#    - The assumption that the brain was a digital computer.
#    - The assumption that the brain was a linear system.
# 1. What is a GPU?
# <br> R: A GPU is a graphics processing unit, which is a specialized processor for handling graphics. The most advanced GPUs is the NVIDIA Tesla V100, which is a GPU that is optimized for deep learning. Other GPUs are optimized for gaming, and are not as good for deep learning.
# 1. Open a notebook and execute a cell containing: `1+1`. What happens?
# <br> R: The cell will execute and the result will be 2.
# 1. Follow through each cell of the stripped version of the notebook for this chapter. Before executing each cell, guess what will happen.
# <br> R: ok
# 1. Complete the Jupyter Notebook online appendix.
# <br> R: The Jupyter Notebook online appendix is here:
#
# 1. Why is it hard to use a traditional computer program to recognize images in a photo?
# <br> R: It is hard to use a traditional computer program to recognize images in a photo because it is hard to write a program that tells a computer how to recognize an image in a photo. There are many transformations that can be applied to an image, and it is hard to write a program that can recognize an image after it has been transformed.
# 1. What did Samuel mean by "weight assignment"?
# <br> R: Samuel meant by "weight assignment" is that the weights are the numbers that are multiplied by the inputs to produce the output.
# 1. What term do we normally use in deep learning for what Samuel called "weights"?
# <br> R: The term that we normally use in deep learning for what Samuel called "weights" is "parameters".
# 1. Draw a picture that summarizes Samuel's view of a machine learning model.
# <br> R: This is a picture that summarizes Samuel's view of a machine learning model:
#    - The inputs are the x's.
#    - The outputs are the y's.
#    - The weights are the w's.
#    - The bias is the b.
#    It shows how the inputs are multiplied by the weights, and then the bias is added to produce the output. A formula for this is:
#    y = w * x + b
#    and a python plot  of this is:
#    ```python
#    def f(x): return x*w+b
#    ```
# 1. Why is it hard to understand why a deep learning model makes a particular prediction?
# <br> R: It is hard to understand why a deep learning model makes a particular prediction because the model is a black box. We don't know what the model is doing inside, so we can't understand why it makes a particular prediction.
# 1. What is the name of the theorem that shows that a neural network can solve any mathematical problem to any level of accuracy?
# <br> R: The name of the theorem that shows that a neural network can solve any mathematical problem to any level of accuracy is the **Universal Approximation Theorem**.
# 1. What do you need in order to train a model?
# <br> R: You need a loss function and some data. The loss function tells you how good your model is, and the data is what you use to train your model. You also need a way to update the parameters of your model, which is called an optimizer. The optimizer is the algorithm that you use to update the parameters of your model. The optimizer is usually called `opt`.
# 1. How could a feedback loop impact the rollout of a predictive policing model?
# <br> R: A feedback loop could impact the rollout of a predictive policing model by causing the model to be biased towards the data that it is given. For example, if the model is used to predict which people are likely to commit crimes, and then the police arrest those people, then the model will be biased towards predicting that those people are likely to commit crimes. This is because the model is being trained on the data that it is given, and the data that it is given is biased towards the people that the police arrest.
# 1. Do we always have to use 224×224-pixel images with the cat recognition model?
# <br> R: No, we don't always have to use 224×224-pixel images with the cat recognition model. We can use any size of image, but the model will be trained on 224×224-pixel images, so it will work best with images that are the same size as the images that it was trained on.
# 1. What is the difference between classification and regression?
# <br> R: Classification is when the output is a category, and regression is when the output is a number. For example, if you are trying to predict whether a photo is a picture of a cat or a dog, then this is a classification problem. If you are trying to predict the price of a house, then this is a regression problem.
# 1. What is a validation set? What is a test set? Why do we need them?
# <br> R: A validation set is a set of data that you use to check how well your model is doing. A test set is a set of data that you use to check how well your model is doing, but you only use it once. You use the validation set to check how well your model is doing while you are training it, and you use the test set to check how well your model is doing after you have finished training it. You need them because you need to check how well your model is doing, and you need to check how well your model is doing on data that it hasn't seen before.
# 1. What will fastai do if you don't provide a validation set?
# <br> R: If you don't provide a validation set, fastai will split the training set into a training set and a validation set. The validation set will be 20% of the training set.
# 1. Can we always use a random sample for a validation set? Why or why not?
# <br> R: We can't always use a random sample for a validation set. We can't always use a random sample for a validation set because we need to check how well our model is doing on data that it hasn't seen before. If we use a random sample for a validation set, then we are checking how well our model is doing on data that it has seen before, and this is not a good way to check how well our model is doing.
# 1. What is overfitting? Provide an example.
# <br> R: Overfitting happends when your model is too good at predicting the training set. For example, if you have a model that is trained to recognize cats, and it is so good at recognizing cats that it can recognize cats that are in the training set, but it can't recognize cats that are not in the training set, then this is overfitting.
# 1. What is a metric? How does it differ from "loss"?
# <br> R: A metric is a way to measure how well your model is doing. It is different from "loss" because "loss" is a way to measure how well your model is doing, but it is only used while you are training your model. A metric is used to measure how well your model is doing after you have finished training your model.
# 1. How can pretrained models help?
# <br> R: Pretrained models can help because they have already been trained on a lot of data, so they are already good at recognizing images. This means that you don't have to train your model on a lot of data, and you can use a smaller dataset to train your model.
# 1. What is the "head" of a model?
# <br> R: The "head" of a model is the part of the model that is added on to the pretrained model. The pretrained model is the part of the model that is already trained, and the "head" is the part of the model that is added on to the pretrained model. For example, if you are using a pretrained model to recognize cats, then the pretrained model is the part of the model that is already trained to recognize cats, and the "head" is the part of the model that is added on to the pretrained model to recognize cats.
# 1. What kinds of features do the early layers of a CNN find? How about the later layers?
# <br> R: The early layers of a CNN find features that are very simple, like lines and edges. The later layers of a CNN find features that are more complex, like eyes and ears.
# 1. Are image models only useful for photos?
# <br> R: Image models are not only useful for photos. They are also useful for videos, and they are also useful for text.
# 1. What is an "architecture"?
# <br> R: An "architecture" is the way that the layers of a model are connected together. For example, if you have a model that has a convolutional layer, a pooling layer, and a fully connected layer, then this is an "architecture". Other examples of "architectures" are ResNet and Inception.
# 1. What is segmentation?
# <br> R: Segmentation is when you try to predict what each pixel in an image is. For example, if you are trying to predict what each pixel in an image is, then this is segmentation. It is important to note that segmentation is different from classification. Classification is when you try to predict what category an image is, and segmentation is when you try to predict what each pixel in an image is. This is an important problem because it is useful for self-driving cars, and it is useful for medical imaging.
# 1. What is `y_range` used for? When do we need it?
# <br> R: `y_range` is used for regression. We need it when we are trying to predict a number, and we need it when we are trying to predict a number that is not between 0 and 1. For example, if we are trying to predict the price of a house, then we need `y_range` because the price of a house is not between 0 and 1. If it is between 0 and 1, then we don't need `y_range` and we use `sigmoid_range` instead or a loss function that is designed for regression like `MSELossFlat` or `L1LossFlat` or `SmoothL1LossFlat` or `HuberLossFlat`.
# 1. What are "hyperparameters"?
# <br> R: Hyperparameters are the parameters that you can change when you are training your model. For example, the learning rate is a hyperparameter. Another example of a hyperparameter is the number of epochs. Other examples of a hyperparameter is the batch size, optimizer, loss function, and metrics.
# 1. What's the best way to avoid failures when using AI in an organization?
# <br> R: The best way to avoid failures when using AI in an organization is to make sure that you have a good understanding of the data that you are using to train your model.

# %% [markdown]
# # Further Research

# %% [markdown]
# 1. Why is a GPU useful for deep learning? How is a CPU different, and why is it less effective for deep learning?
# <br> R: A GPU is useful for deep learning because it is good at doing a lot of calculations at the same time. A CPU is different because it is not good at doing a lot of calculations at the same time. This is why it is less effective for deep learning. CPUs are good at doing one thing at a time, but GPUs are good at doing a lot of things at the same time. C stands for central, and P stands for processing. G stands for graphics, and P stands for processing.
# 1. Try to think of three areas where feedback loops might impact the use of machine learning. See if you can find documented examples of that happening in practice.
# <br> R: Feedback loops can impact the use of machine learning in various ways:
#     - In recommender systems, feedback loops can lead to a narrow range of recommendations
#     - In social media, feedback loops can create echo chambers and reinforce existing biases
#     - In automated decision-making systems, feedback loops can perpetuate and amplify biases present in the training data. </br>
# These feedback loops can have significant consequences, such as the reinforcement of harmful stereotypes and the unequal treatment of certain groups.

# %% [markdown]
# # Conclusion
#
# Deep learning is a powerful tool for solving complex problems and has achieved impressive results in various tasks such as image classification, natural language processing, and speech recognition.
#
# It requires ***large amounts of data*** and mathematical calculations, but does not necessarily need expensive computers or a PhD.
#
# The first device based on artificial neurons was called a perceptron, and the requirements for parallel distributed processing (PDP) include parallelism, distribution of representations, propagation of activity, and localist coding.
#
# Misconceptions about the brain being a digital computer or a linear system hindered the development of neural networks in the past.
#
# A GPU is a specialized processor for graphics and performing many calculations simultaneously.
#
# It is difficult to use a traditional computer program to recognize images in a photo due to the difficulty of writing a program that can recognize an image after it has been transformed.
#
# The universal approximation theorem states that a neural network can approximate any continuous function, and the backpropagation algorithm is used to train neural networks by adjusting the weights to minimize the error between the predicted and true output.
#
# It is important to ensure the training data is representative of real-world data and to monitor the model's performance on test data to prevent overfitting.
#
# Deep learning has the potential to revolutionize many fields and has already achieved impressive results in various tasks.
