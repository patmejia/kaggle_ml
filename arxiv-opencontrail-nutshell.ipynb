# %% [markdown]
# <a href="https://www.kaggle.com/code/patimejia/arxiv-opencontrail-nutshell?scriptVersionId=136510274" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
from IPython.display import Image, display, Markdown, HTML
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

html_str = """
<h1>ArXiv OpenContrails in a Nutshell</h1>

<h3>Images followed by Tables:</h3>
"""

images = ['/kaggle/input/contrail-vision-research-related-images-docs/title.png',
          '/kaggle/input/contrail-vision-research-related-images-docs/fig1_examples_labels.png',
          '/kaggle/input/contrail-vision-research-related-images-docs/fig2_3_true_color.png',
          '/kaggle/input/contrail-vision-research-related-images-docs/fig4_sequence.png',
          '/kaggle/input/contrail-vision-research-related-images-docs/fig5_night_day.png',
          '/kaggle/input/contrail-vision-research-related-images-docs/fig6_lat_long.png',
          '/kaggle/input/contrail-vision-research-related-images-docs/fig7_8_cloud_stats.png',
          '/kaggle/input/contrail-vision-research-related-images-docs/fig9_network_architecture.png',
          '/kaggle/input/contrail-vision-research-related-images-docs/fig10_11_precision_recall__multiframe.png',
          '/kaggle/input/contrail-vision-research-related-images-docs/fig12_diff_spatial_location.png',
          '/kaggle/input/contrail-vision-research-related-images-docs/fig13_14_precision_zenith_cloud_cover.png',
          '/kaggle/input/contrail-vision-research-related-images-docs/fig15_linear_contrail_flight_density.png',
          '/kaggle/input/contrail-vision-research-related-images-docs/fig16_linear_coverage_single.png',
          '/kaggle/input/contrail-vision-research-related-images-docs/fig17_contrail_flights.png',
          '/kaggle/input/contrail-vision-research-related-images-docs/fig18_model_detection_output.png',
          '/kaggle/input/contrail-vision-research-related-images-docs/table1_diff_architecture.png',
          '/kaggle/input/contrail-vision-research-related-images-docs/table2_multi_frame.png',
          '/kaggle/input/contrail-vision-research-related-images-docs/table3_performance.png',
          '/kaggle/input/contrail-vision-research-related-images-docs/table4_meijer_et_al_detection.png']

display(HTML(html_str))

fig, axs = plt.subplots(len(images), 1, figsize=(10, len(images)*5))
for i, image in enumerate(images):
    img = mpimg.imread(image)
    axs[i].imshow(img)
    axs[i].axis('off')
plt.tight_layout()
plt.show()
# Out:
# <h1>ArXiv OpenContrails in a Nutshell</h1>
#
# <h3>Images followed by Tables:</h3>

# %%
ack_str = """
<h3>Acknowledgements:</h3>
<ul>
  <li><strong>Article:</strong> <em>OpenContrails: Benchmarking Contrail Detection on GOES-16 ABI</em> by Ng, Joe Yue-Hei; McCloskey, Kevin; Cui, Jian; Meijer, Vincent; Brand, Erica; Sarna, Aaron; Goyal, Nita; Van Arsdale, Christopher; Geraedts, Scott (<a href='https://arxiv.org/abs/2304.02122'>arXiv:2304.02122</a>, 2023)</li>
  <li><strong>Dataset:</strong> goes_contrails_dataset from the OpenContrails project</li>
  <li><strong>Competition:</strong> google-research-identify-contrails-reduce-global-warming</li>
</ul>
"""

display(HTML(ack_str))
# Out:
# <h3>Acknowledgements:</h3>
# <ul>
#   <li><strong>Article:</strong> <em>OpenContrails: Benchmarking Contrail Detection on GOES-16 ABI</em> by Ng, Joe Yue-Hei; McCloskey, Kevin; Cui, Jian; Meijer, Vincent; Brand, Erica; Sarna, Aaron; Goyal, Nita; Van Arsdale, Christopher; Geraedts, Scott (<a href='https://arxiv.org/abs/2304.02122'>arXiv:2304.02122</a>, 2023)</li>
#   <li><strong>Dataset:</strong> goes_contrails_dataset from the OpenContrails project</li>
#   <li><strong>Competition:</strong> google-research-identify-contrails-reduce-global-warming</li>
# </ul>

# %% [markdown]
# <div style="background-color: #f2f2f2; padding: 53px; border-radius: 5px;">
#   <h3>If you found this notebook helpful...</h3>
#   <p>
#   Please consider giving it a star. Your support helps me continue to develop high-quality code and pursue my career as a data analyst/engineer. Feedback is always welcome and appreciated. Thank you for taking the time to read my work!
#   </p>
#   <h4>
#   <p style="text-align: right;">
#   <a href="https://github.com/patmejia"> - pat [¬º-°]¬ </a>
#   </h4>
#   </p>
# </div>
