# %% [markdown]
# <a href="https://www.kaggle.com/code/patimejia/adding-images-kernel?scriptVersionId=110134202" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# Hello,
#
# Here are two 🍳 easy steps to add locally stored images to your notebooks for either **markdown** or **code** cells.
#
# This method may work for Mac, Linux, and Windows users, but I have only tested it on Mac.
#
# # Adding images to markdown cells
#
# ## Step 1:
#
# Upload your images to Kaggle as a new Dataset.
#
# ![new_dataset](https://storage.googleapis.com/kagglesdsdata/datasets/2603287/4445539/new_dataset.png?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=databundle-worker-v2%40kaggle-161607.iam.gserviceaccount.com%2F20221104%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20221104T011821Z&X-Goog-Expires=345600&X-Goog-SignedHeaders=host&X-Goog-Signature=...)
#
# ## Step 2:
#
# Right-click on the image, click on `copy image address` and paste it into your notebook.
#
# For example,
# input:
# ```
# ![copy_image_address](https://storage.googleapis.com/kagglesdsdata/datasets/2603287/4445539/copy_image_address.png?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=databundle-worker-v2%40kaggle-161607.iam.gserviceaccount.com%2F20221104%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20221104T011655Z&X-Goog-Expires=345600&X-Goog-SignedHeaders=host&X-Goog-Signature=...)
# ```
# output:
# ![copy_image_address](https://storage.googleapis.com/kagglesdsdata/datasets/2603287/4445539/copy_image_address.png?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=databundle-worker-v2%40kaggle-161607.iam.gserviceaccount.com%2F20221104%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20221104T011655Z&X-Goog-Expires=345600&X-Goog-SignedHeaders=host&X-Goog-Signature=...)
#
# # Adding images to code cells
#
# Do the same 2 steps as above, but instead of pasting the image address into a markdown cell, paste it into a code cell.
#
# For example,
#
# input:
# ```python
# # insert and image that has an url and a caption
# # the image is inserted in the current cell
# # the caption is inserted in a new cell
# # the new cell is inserted after the current cell
#
# import os
# import sys
# import urllib.request
# import json
# import base64
# import IPython.display
# import IPython.core.display
# import IPython.core.displaypub
#
# def insert_image(url, caption):
#     # get the image
#     image = urllib.request.urlopen(url).read()
#     # encode the image
#     image = base64.b64encode(image).decode('utf-8')
#     # create the html
#     html = f"""<img src="data:image/png;base64,{image}" alt="{caption}" title="{caption}" />"""
#     # display the image
#     IPython.display.display(IPython.display.HTML(html))
#     # create the caption
#     IPython.display.display(IPython.display.Markdown(f"""# {caption}"""))
#
# # insert the image
# insert_image("https://storage.googleapis.com/kagglesdsdata/datasets/2603287/4445539/copy_image_address.png?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=databundle-worker-v2%40kaggle-161607.iam.gserviceaccount.com%2F20221104%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20221104T011655Z&X-Goog-Expires=345600&X-Goog-SignedHeaders=host&X-Goog-Signature=...", "copy_image_address_screenshot")
# ```
# output:
# ![code_cell](https://storage.googleapis.com/kagglesdsdata/datasets/2603287/4445735/code_cell.png?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=databundle-worker-v2%40kaggle-161607.iam.gserviceaccount.com%2F20221104%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20221104T022659Z&X-Goog-Expires=345600&X-Goog-SignedHeaders=host&X-Goog-Signature=...)
#
# See notebook with full example of adding image into a **code cell** or in the **kernel** [**here**](https://www.kaggle.com/patimejia/adding-images-kernel/edit).
#
# # Conclusion
#
# This method is a straightforward solution to adding images to your notebooks. It works every time you can copy the image address from the browser.
#
# Congratulations! You have successfully added images to your notebook.

# %% [markdown]
# # Inserting image into a code cell
#
# The address for the images is:
#
# ```
# https://storage.googleapis.com/kagglesdsdata/datasets/2603287/4445539/copy_image_address.png?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=databundle-worker-v2%40kaggle-161607.iam.gserviceaccount.com%2F20221104%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20221104T011655Z&X-Goog-Expires=345600&X-Goog-SignedHeaders=host&X-Goog-Signature=...
# ```

# %% [markdown]
# ### see full discussion [here](https://www.kaggle.com/discussions/getting-started/48803#2016436)

# %%
# insert and image that has an url and a caption
# the image is inserted in the current cell
# the caption is inserted in a new cell
# the new cell is inserted after the current cell

import os
import sys
import urllib.request
import json
import base64
import IPython.display
import IPython.core.display
import IPython.core.displaypub

def insert_image(url, caption):
    # get the image
    image = urllib.request.urlopen(url).read()
    # encode the image
    image = base64.b64encode(image).decode('utf-8')
    # create the html
    html = f"""<img src="data:image/png;base64,{image}" alt="{caption}" title="{caption}" />"""
    # display the image
    IPython.display.display(IPython.display.HTML(html))
    # create the caption
    IPython.display.display(IPython.display.Markdown(f"""# {caption}"""))

# insert the image
insert_image("https://storage.googleapis.com/kagglesdsdata/datasets/2603287/4445539/copy_image_address.png?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=databundle-worker-v2%40kaggle-161607.iam.gserviceaccount.com%2F20221104%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20221104T011655Z&X-Goog-Expires=345600&X-Goog-SignedHeaders=host&X-Goog-Signature=...", "copy_image_address_screenshot")
# Out:
# <img src="data:image/png;base64,..." alt="copy_image_address_screenshot" title="copy_image_address_screenshot" />
# # copy_image_address_screenshot
